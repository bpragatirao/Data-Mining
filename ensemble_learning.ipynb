# %% [markdown]
# ## <u>Marquis de Condorcet's Jury Theorem</u>

# %% [markdown]
# ### - A Theorem From
# ### - Political science theorem
# ### - Relative probability of a given group of individuals arriving at a correct majority decision.

# %% [markdown]
# ### <u>The theorem says that:</u>
# ### If each person is more than 50% correct,
# ### then adding more people to vote increases the probability that the majority is correct.
#
# <hr>

# %% [markdown]
# ### Suppose we have a tree with 60% accuracy
# <img src="image/tree_1.png" width="200">
# <img src="image/tree_acc_1.png" width="250">
#
# <hr>

# %% [markdown]
# ### Suppose we have add <u>two more trees</u> also with 60% accuracy
# <img src="image/tree_2.png" width="300">
# <img src="image/tree_acc_2.png" width="250">
#
# ### - Decide by the majority vote,
# ### - then the probability of the vote being right goes up to 65%!
#
# <hr>

# %% [markdown]
# ### The theorem suggests that the probability of the majority vote being correct can go up as we add more and more models.
#
# <img src="image/tree_3.png" width="350">
# <img src="image/tree_acc_3.png" width="265">
#
# ### With eleven models, the majority can reach 75% accuracy!
#
# <hr>

# %% [markdown]
# ## <u> However </u>
# ### - The accuracy may not improve if each model produces the same prediction.
# ### - For Example:

# %% [markdown]
# - ### The mistake of one model would not be caught by the other models.
# - ### Therefore, we would want to cast a majority vote using the models that are different.

# %% [markdown]
# ## In machine learning, this concept of multiple models working together to come to an aggregate prediction is called <u>ensemble learning.</u>
#
# <hr>
# <hr>

# %% [markdown]
# ## Ensemble Learning

# %% [markdown]
# ### Creates a stronger model by aggregating the predictions of multiple <u>weak models.</u>
#
# <img src="image/ensemble.png" width="700">

# %% [markdown]
# ### <u>Weak Models:</u>

# %% [markdown]
# - ### Slightly better than random guessing
# - ### Classification: Accuracy just above random chance (e.g., > 50% for binary classification)
# - ### Regression: Error slightly better than a trivial predictor (mean/median)

# %% [markdown]
# # Bagging

# %% [markdown]
# ### How to create multiple models <u>that are different</u>?
# - ### Train each model using a different training set
#
# ### <u>Bootstrap Aggregating method :</u>
# - ### Random sampling with replacement
# - ### This means that a data point can be drawn more than once.
# - ### This results in several training sets that are different.

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Task: Building a random forest model to classify if a road sign is a pedestrian crossing sign or not.
#
# ### Dataset Features:
# - ### Size,
# - ### number of sides,
# - ### number of colors used, and
# - ### if the sign has text or symbol.

# %% [markdown]
# ### Dataset Generation: Bagging method
# <img src="image/dataset.png" width="400">

# %% [markdown]
# <img src="image/samples.png" width="400">

# %% [markdown]
# ### For each sample:
# - ### Create a decision tree
# - ### A new random subset of features is selected at every split
# - ### This ensures that the decision trees are as different as possible.

# %% [markdown]
# <img src="image/rf_1.png" width="400">

# %% [markdown]
# <img src="image/rf_2.png" width="400">

# %% [markdown]
# ## <u>Here are trees built from each sample.</u>

# %% [markdown]
# ### Notice how these trees are quite different from each other.
#
# <img src="image/rf_3.png" width="600">

# %% [markdown]
# ## Each tree produces a prediction.
#
# <img src="image/rf_4.png" width="600">
#
# <hr>

# %% [markdown]
# ## <u>Drawback of Decision Trees</u>

# %% [markdown]
# ### Suffer from high variance
# - ### Small changes in the training data can produce very different trees
# - ### Greedy splitting
# - ### Hierarchical structure (error propagation)
# - ### Hard decisions
# - ### Overfitting deep trees
# - ### No built-in regularization

# %% [markdown]
# ## <u>However</u>
# - ### This variance among trees is employed in the random forest as a <u>feature, not a bug.</u>

# %% [markdown]
# ## Leo Breiman: Inventor of Random Forest model says,
# - ### "Our results indicate that better (lower generalization error) random forests have lower correlation between classifiers and higher strength."
# - ### The high variance of the decision tree model can help keep the correlation among trees low.
# - ### The <u>Bagging Method</u> as well as the <u>Feature Selection</u> are the key innovations to <u>keep correlation low.</u>

# %% [markdown]
# ## <u>Variance in Predictions</u>
# ### If each tree produces the same prediction, then the accuracy can not improve.

# %% [markdown]
# Source: https://mlu-explain.github.io/random-forest/
